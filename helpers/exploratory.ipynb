# %%
import sys
sys.path.append("../")

import numpy as np 
import pandas as pd
import DataLoader as dl

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML

from sklearn import metrics
from mixed_naive_bayes import MixedNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
loader = dl.Data()
digits = loader.loadData('Emnist', 'Digits')
letters = loader.loadData('Emnist', 'Letters')

# Get x and y from data
x_digits = loader.getX(digits)
y_digits = loader.getY(digits)

x_letters = loader.getX(letters)
y_letters = loader.getY(letters)

# %%
import seaborn as sb

sb.set_style("whitegrid")
sb.displot(data=digits, x='a784', height=6)

# %%
sb.set_style("whitegrid")
sb.displot(data=letters, x='a784', height=6)
